# %% [markdown]
# ## Part 8: Reflection and Conclusion
#
# In this final part, we reflect on what we have learned throughout the tutorial and connect these findings to real-world implications.
#
# You have:
# - measured overall and subgroup performance
# - identified disparities across demographic groups
# - used three different trained models on datasets with different distributions
# - observed how changes in data affect outcomes
#
# Now, consider what these results mean.

# %% [markdown]
# ### Reflection: Choosing a Model
#
# You trained multiple models using datasets with different demographic distributions. Which model would you choose to deploy in a real-world setting?
#
# In your answer, consider:
# - overall accuracy
# - differences in performance across groups
# - potential impact on different populations

# %%
# Write your response here.

# %% [markdown]
# ### Reflection: What caused the bias?
#
# Based on your results, explain how training data imbalance led to differences in model performance.
# Focus on:
# - how dataset composition affected outcomes
# - which groups were most impacted

# %%
# Write your response here.

# %% [markdown]
# ### Real-World Implications
#
# Facial recognition systems are used in areas such as security, policing, and identity verification. When these systems perform unevenly across groups, the consequences are not evenly distributed.
#
# Reflect on:
# - who is most likely affected by higher error rates
# - what risks arise when bias is not examined
# - why data collection and dataset design matter

# %%
# Write your response here.

# %% [markdown]
# ### Final Takeaway
#
# In this tutorial, you learned how to move beyond overall accuracy to examine how machine learning systems behave across different groups.
#
# You also saw that:
# - bias can be measured through performance differences
# - training data plays a key role in shaping outcomes
# - systems that appear accurate overall may still produce unequal results
#
# Understanding these patterns is essential for building and evaluating responsible machine learning systems. As you continue studying computer science, keep in mind how the data and decisions behind a system can shape its real-world impact.
#
# We wish you the best in your future journey in computer science!
